# %%
#Enter only uppercase letters
import time
import random

time.sleep(1)

words = ["WHDSPQZ", "XHO", "TTDBFRT", "QQJYF", "ENQD", "DNPK", "CNTR", "EHWHOD", "TSVMOHOF", "XNOCFQGTM"]

#Word will be randomly chosen from list of words
word = random.choice(words)

print("Guess the characters in the word. Enter uppercase letter only")

guesses = ""

turns = 10

while turns > 0:
    failed = 0
    for char in word:
        if char in guesses:
            print(char)
        else:
            print("-")
            failed += 1
    #If user wins, win message will appear. Print correct word  
    if failed == 0:
        print("You win!")
        print("The word is:", word)
        break
    
    guess = input("guess a character:")
    
    guesses += guess
    #remove turn if user guesses wrong
    if guess not in word:
        turns -= 1
        print("Wrong")
        
    print("You have", +turns, "more guesses")
    #If user loses, lose message will appear. Print correct word
    if turns == 0:
        print("You Lose")
        print("The word is:", word)
# Out:
# Guess the characters in the word. Enter uppercase letter only
# -
# -
# -
# -
# guess a character:O
# Wrong
# You have 9 more guesses
# -
# -
# -
# -
# guess a character:F
# Wrong
# You have 8 more guesses
# -
# -
# -
# -
# guess a character:R
# Wrong
# You have 7 more guesses
# -
# -
# -
# -
# guess a character:S
# Wrong
# You have 6 more guesses
# -
# -
# -
# -
# guess a character:F
# Wrong
# You have 5 more guesses
# -
# -
# -
# -
# guess a character:V
# Wrong
# You have 4 more guesses
# -
# -
# -
# -
# guess a character:E
# Wrong
# You have 3 more guesses
# -
# -
# -
# -
# guess a character:N
# You have 3 more guesses
# -
# N
# -
# -
# guess a character:R
# Wrong
# You have 2 more guesses
# -
# N
# -
# -
# guess a character:S
# Wrong
# You have 1 more guesses
# -
# N
# -
# -
# guess a character:E
# Wrong
# You have 0 more guesses
# You Lose
# The word is: DNPK
